# %% [markdown]
# ## Summary of Data
#
# The LinkedIn data set provided contains 7,927 rows and 15 columns, providing a comprehensive overview of job postings on the platform. The data can be used for data analysis, visualization, and research. The job postings include Data Analyst, Machine Learning Engineer, IT Services and IT Consulting roles, located in various locations around the world, with varying salaries and work hours. The data set includes information about the company, role responsibilities, and required skills for each job. This data set is a valuable resource for understanding job opportunities in different industries and locations.

# %% [markdown]
# ## Understanding the Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("linkdin_Job_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7927 entries, 0 to 7926
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_ID              7927 non-null   int64
#  1   job                 7894 non-null   object
#  2   location            7894 non-null   object
#  3   company_id          0 non-null      float64
#  4   company_name        7892 non-null   object
#  5   work_type           7736 non-null   object
#  6   full_time_remote    7848 non-null   object
#  7   no_of_employ        7603 non-null   object
#  8   no_of_application   7887 non-null   object
#  9   posted_day_ago      7920 non-null   object
#  10  alumni              4858 non-null   object
#  11  Hiring_person       5720 non-null   object
#  12  linkedin_followers  4814 non-null   object
#  13  hiring_person_link  5720 non-null   object
#  14  job_details         7881 non-null   object
#  15  Column1             0 non-null      float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 991.0+ KB

# %%
df.dtypes
# Out:
# job_ID                  int64
# job                    object
# location               object
# company_id            float64
# company_name           object
# work_type              object
# full_time_remote       object
# no_of_employ           object
# no_of_application      object
# posted_day_ago         object
# alumni                 object
# Hiring_person          object
# linkedin_followers     object
# hiring_person_link     object
# job_details            object
# Column1               float64
# dtype: object

# %%
df[df.duplicated(subset=['job_ID'])].count()
# Out:
# job_ID                2084
# job                   2078
# location              2078
# company_id               0
# company_name          2077
# work_type             2025
# full_time_remote      2072
# no_of_employ          1989
# no_of_application     2077
# posted_day_ago        2083
# alumni                1272
# Hiring_person         1563
# linkedin_followers    1284
# hiring_person_link    1563
# job_details           2076
# Column1                  0
# dtype: int64

# %%
df.shape
# Out:
# (7927, 16)

# %%
df.head()
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         NaN                 Crossover
# 1         New Delhi, Delhi, India         NaN                 Crossover
# 2          Greater Bengaluru Area         NaN                    Uplers
# 3        Gurugram, Haryana, India         NaN             PVAR SERVICES
# 4  Mohali district, Punjab, India         NaN  Timeline Freight Brokers
#
#   work_type              full_time_remote  \
# 0    Remote         Full-time · Associate
# 1    Remote         Full-time · Associate
# 2    Remote  Full-time · Mid-Senior level
# 3   On-site                     Full-time
# 4   On-site                     Full-time
#
#                                         no_of_employ no_of_application  \
# 0  1,001-5,000 employees · IT Services and IT Con...               200
# 1  1,001-5,000 employees · IT Services and IT Con...               184
# 2  1,001-5,000 employees · IT Services and IT Con...               200
# 3                                     1-10 employees               200
# 4                                     1-10 employees                 8
#
#   posted_day_ago             alumni           Hiring_person  \
# 0        8 hours  12 company alumni                     NaN
# 1        8 hours  12 company alumni                     NaN
# 2        9 hours   3 company alumni            Shahid Ahmad
# 3        7 hours                NaN           Vartika Singh
# 4     26 minutes   1 company alumni  Manisha (Gisele Smith)
#
#     linkedin_followers                                 hiring_person_link  \
# 0  5,395,547 followers                                                NaN
# 1  5,395,547 followers                                                NaN
# 2                  NaN  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3      2,094 followers         https://www.linkedin.com/in/vartika-singh-
# 4                  NaN     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details  Column1
# 0  About the job Crossover is the world's #1 sour...      NaN
# 1  About the job Crossover is the world's #1 sour...      NaN
# 2  About the job Profile: ML EngineersExperience:...      NaN
# 3  About the job Designation: Data AnalystLocatio...      NaN
# 4  About the job The ideal candidate will use the...      NaN

# %% [markdown]
# There are several duplicate rows and missing values in the dataset that needs to be dealt with. There are also some columns that are completely missing any sort of data that either needs to be filled or removed.

# %% [markdown]
# ## Data Cleaning

# %%
df_clean = df.copy()

# %% [markdown]
# Removing duplicate rows within the dataset and reindexing the values.

# %%
df_clean.drop_duplicates(subset=['job_ID'], inplace=True)
df_clean.reset_index(inplace=True)
df_clean.drop(columns='index', inplace=True)

# %%
df_clean.shape
# Out:
# (5843, 16)

# %% [markdown]
# Fill the company_ID column by assigning a unique identifier based on the company_name's order of appearance alphabetically.

# %%
df_clean['company_id'] = df_clean.groupby('company_name').ngroup()
df_clean.head()
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         523                 Crossover
# 1         New Delhi, Delhi, India         523                 Crossover
# 2          Greater Bengaluru Area        2241                    Uplers
# 3        Gurugram, Haryana, India        1552             PVAR SERVICES
# 4  Mohali district, Punjab, India        2146  Timeline Freight Brokers
#
#   work_type              full_time_remote  \
# 0    Remote         Full-time · Associate
# 1    Remote         Full-time · Associate
# 2    Remote  Full-time · Mid-Senior level
# 3   On-site                     Full-time
# 4   On-site                     Full-time
#
#                                         no_of_employ no_of_application  \
# 0  1,001-5,000 employees · IT Services and IT Con...               200
# 1  1,001-5,000 employees · IT Services and IT Con...               184
# 2  1,001-5,000 employees · IT Services and IT Con...               200
# 3                                     1-10 employees               200
# 4                                     1-10 employees                 8
#
#   posted_day_ago             alumni           Hiring_person  \
# 0        8 hours  12 company alumni                     NaN
# 1        8 hours  12 company alumni                     NaN
# 2        9 hours   3 company alumni            Shahid Ahmad
# 3        7 hours                NaN           Vartika Singh
# 4     26 minutes   1 company alumni  Manisha (Gisele Smith)
#
#     linkedin_followers                                 hiring_person_link  \
# 0  5,395,547 followers                                                NaN
# 1  5,395,547 followers                                                NaN
# 2                  NaN  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3      2,094 followers         https://www.linkedin.com/in/vartika-singh-
# 4                  NaN     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details  Column1
# 0  About the job Crossover is the world's #1 sour...      NaN
# 1  About the job Crossover is the world's #1 sour...      NaN
# 2  About the job Profile: ML EngineersExperience:...      NaN
# 3  About the job Designation: Data AnalystLocatio...      NaN
# 4  About the job The ideal candidate will use the...      NaN

# %% [markdown]
# Split the full_time_remote and no_of_employ columns as they contain more information than it should.

# %%
df_clean[['full_time_remote', 'job_level']] = df_clean['full_time_remote'].str.split('·', 2, expand=True)

# %%
df_clean['no_of_employ'] = df_clean['no_of_employ'].str.replace(',', '')
df_clean['no_of_employ'] = df_clean['no_of_employ'].str.replace('employees', '')

# %%
df_clean[['no_of_employ', 'industry']] = df_clean['no_of_employ'].str.split('·', 2, expand=True)

# %%
df_clean.head()
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         523                 Crossover
# 1         New Delhi, Delhi, India         523                 Crossover
# 2          Greater Bengaluru Area        2241                    Uplers
# 3        Gurugram, Haryana, India        1552             PVAR SERVICES
# 4  Mohali district, Punjab, India        2146  Timeline Freight Brokers
#
#   work_type full_time_remote no_of_employ no_of_application posted_day_ago  \
# 0    Remote       Full-time   1001-5000                 200        8 hours
# 1    Remote       Full-time   1001-5000                 184        8 hours
# 2    Remote       Full-time   1001-5000                 200        9 hours
# 3   On-site        Full-time        1-10                200        7 hours
# 4   On-site        Full-time        1-10                  8     26 minutes
#
#               alumni           Hiring_person   linkedin_followers  \
# 0  12 company alumni                     NaN  5,395,547 followers
# 1  12 company alumni                     NaN  5,395,547 followers
# 2   3 company alumni            Shahid Ahmad                  NaN
# 3                NaN           Vartika Singh      2,094 followers
# 4   1 company alumni  Manisha (Gisele Smith)                  NaN
#
#                                   hiring_person_link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3         https://www.linkedin.com/in/vartika-singh-
# 4     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details  Column1  \
# 0  About the job Crossover is the world's #1 sour...      NaN
# 1  About the job Crossover is the world's #1 sour...      NaN
# 2  About the job Profile: ML EngineersExperience:...      NaN
# 3  About the job Designation: Data AnalystLocatio...      NaN
# 4  About the job The ideal candidate will use the...      NaN
#
#            job_level                        industry
# 0          Associate   IT Services and IT Consulting
# 1          Associate   IT Services and IT Consulting
# 2   Mid-Senior level   IT Services and IT Consulting
# 3               None                            None
# 4               None                            None

# %% [markdown]
# Remove all unnecessary text from no_of_application column.

# %%
for i in ['days','day','seconds','minutes','minute','hours','hour']:
    df_clean['no_of_application'] = df_clean['no_of_application'].str.replace(i, '')

# %%
df_clean['no_of_application'] = pd.to_numeric(df_clean['no_of_application'])

# %% [markdown]
# Same thing again, remove all unnecessary text from alumni column.

# %%
df_clean['alumni'] = df_clean['alumni'].str.rstrip('company alumni')
df_clean['alumni'] = df_clean['alumni'].str.replace(',', '')
df_clean['alumni'] = pd.to_numeric(df_clean['alumni'])

# %%
df_clean.head()
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         523                 Crossover
# 1         New Delhi, Delhi, India         523                 Crossover
# 2          Greater Bengaluru Area        2241                    Uplers
# 3        Gurugram, Haryana, India        1552             PVAR SERVICES
# 4  Mohali district, Punjab, India        2146  Timeline Freight Brokers
#
#   work_type full_time_remote no_of_employ  no_of_application posted_day_ago  \
# 0    Remote       Full-time   1001-5000                200.0        8 hours
# 1    Remote       Full-time   1001-5000                184.0        8 hours
# 2    Remote       Full-time   1001-5000                200.0        9 hours
# 3   On-site        Full-time        1-10               200.0        7 hours
# 4   On-site        Full-time        1-10                 8.0     26 minutes
#
#    alumni           Hiring_person   linkedin_followers  \
# 0    12.0                     NaN  5,395,547 followers
# 1    12.0                     NaN  5,395,547 followers
# 2     3.0            Shahid Ahmad                  NaN
# 3     NaN           Vartika Singh      2,094 followers
# 4     1.0  Manisha (Gisele Smith)                  NaN
#
#                                   hiring_person_link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3         https://www.linkedin.com/in/vartika-singh-
# 4     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details  Column1  \
# 0  About the job Crossover is the world's #1 sour...      NaN
# 1  About the job Crossover is the world's #1 sour...      NaN
# 2  About the job Profile: ML EngineersExperience:...      NaN
# 3  About the job Designation: Data AnalystLocatio...      NaN
# 4  About the job The ideal candidate will use the...      NaN
#
#            job_level                        industry
# 0          Associate   IT Services and IT Consulting
# 1          Associate   IT Services and IT Consulting
# 2   Mid-Senior level   IT Services and IT Consulting
# 3               None                            None
# 4               None                            None

# %% [markdown]
# Remove any extra names in parentheses so the Hiring_person column only has their first and last names. Also change any nan values to 'Not Available' if there is no hiring person.

# %%
df_clean['Hiring_person'] = df_clean['Hiring_person'].str.replace(' \(.*\)', '', regex=True)

# %%
df_clean['Hiring_person'].fillna('Not Available', inplace=True)

# %% [markdown]
# Remove all unnecessary text from linkedin_followers column.

# %%
df_clean['linkedin_followers'] = df_clean['linkedin_followers'].str.rstrip('followers')
df_clean['linkedin_followers'] = df_clean['linkedin_followers'].str.replace(',', '')
df_clean['linkedin_followers'] = df_clean['linkedin_followers'].str.extract('(\d+)')
df_clean['linkedin_followers'] = pd.to_numeric(df_clean['linkedin_followers'])

# %%
df_clean.head()
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         523                 Crossover
# 1         New Delhi, Delhi, India         523                 Crossover
# 2          Greater Bengaluru Area        2241                    Uplers
# 3        Gurugram, Haryana, India        1552             PVAR SERVICES
# 4  Mohali district, Punjab, India        2146  Timeline Freight Brokers
#
#   work_type full_time_remote no_of_employ  no_of_application posted_day_ago  \
# 0    Remote       Full-time   1001-5000                200.0        8 hours
# 1    Remote       Full-time   1001-5000                184.0        8 hours
# 2    Remote       Full-time   1001-5000                200.0        9 hours
# 3   On-site        Full-time        1-10               200.0        7 hours
# 4   On-site        Full-time        1-10                 8.0     26 minutes
#
#    alumni  Hiring_person  linkedin_followers  \
# 0    12.0  Not Available           5395547.0
# 1    12.0  Not Available           5395547.0
# 2     3.0   Shahid Ahmad                 NaN
# 3     NaN  Vartika Singh              2094.0
# 4     1.0        Manisha                 NaN
#
#                                   hiring_person_link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3         https://www.linkedin.com/in/vartika-singh-
# 4     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details  Column1  \
# 0  About the job Crossover is the world's #1 sour...      NaN
# 1  About the job Crossover is the world's #1 sour...      NaN
# 2  About the job Profile: ML EngineersExperience:...      NaN
# 3  About the job Designation: Data AnalystLocatio...      NaN
# 4  About the job The ideal candidate will use the...      NaN
#
#            job_level                        industry
# 0          Associate   IT Services and IT Consulting
# 1          Associate   IT Services and IT Consulting
# 2   Mid-Senior level   IT Services and IT Consulting
# 3               None                            None
# 4               None                            None

# %% [markdown]
# Remove any extra information from the job column so it only has the name of the job title or position.

# %%
df_clean['job'] = df_clean['job'].str.replace('\(.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.replace('\[.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.replace(',.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.replace('–.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.replace('-.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.replace('\|.*', '', regex=True)
df_clean['job'] = df_clean['job'].str.rstrip(' ')

# %% [markdown]
# Split the location column into three separate columns that lists the Country, State, and City.

# %%
df_clean['location'].fillna('', inplace=True)

# %%
df_clean['location'] = df_clean['location'].str.split(',').apply(reversed).apply(','.join)

# %%
df_clean[['Country', 'State', 'City']] = df_clean['location'].str.split(',', 2, expand=True)

# %%
df_clean.head()
# Out:
#        job_ID           job                        location  company_id  \
# 0  3471657636  Data Analyst              India, Delhi,Delhi         523
# 1  3471669068  Data Analyst          India, Delhi,New Delhi         523
# 2  3474349934  Data Analyst          Greater Bengaluru Area        2241
# 3  3472816027  Data Analyst         India, Haryana,Gurugram        1552
# 4  3473311511  Data Analyst   India, Punjab,Mohali district        2146
#
#                company_name work_type full_time_remote no_of_employ  \
# 0                 Crossover    Remote       Full-time   1001-5000
# 1                 Crossover    Remote       Full-time   1001-5000
# 2                    Uplers    Remote       Full-time   1001-5000
# 3             PVAR SERVICES   On-site        Full-time        1-10
# 4  Timeline Freight Brokers   On-site        Full-time        1-10
#
#    no_of_application posted_day_ago  ...  Hiring_person linkedin_followers  \
# 0              200.0        8 hours  ...  Not Available          5395547.0
# 1              184.0        8 hours  ...  Not Available          5395547.0
# 2              200.0        9 hours  ...   Shahid Ahmad                NaN
# 3              200.0        7 hours  ...  Vartika Singh             2094.0
# 4                8.0     26 minutes  ...        Manisha                NaN
#
#                                   hiring_person_link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3         https://www.linkedin.com/in/vartika-singh-
# 4     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details Column1  \
# 0  About the job Crossover is the world's #1 sour...     NaN
# 1  About the job Crossover is the world's #1 sour...     NaN
# 2  About the job Profile: ML EngineersExperience:...     NaN
# 3  About the job Designation: Data AnalystLocatio...     NaN
# 4  About the job The ideal candidate will use the...     NaN
#
#            job_level                        industry                 Country  \
# 0          Associate   IT Services and IT Consulting                   India
# 1          Associate   IT Services and IT Consulting                   India
# 2   Mid-Senior level   IT Services and IT Consulting  Greater Bengaluru Area
# 3               None                            None                   India
# 4               None                            None                   India
#
#       State             City
# 0     Delhi            Delhi
# 1     Delhi        New Delhi
# 2      None             None
# 3   Haryana         Gurugram
# 4    Punjab  Mohali district
#
# [5 rows x 21 columns]

# %% [markdown]
# Remove any extra columns that are no longer being used and rename columns so that they are consistent.

# %%
df_clean.drop(columns=['Column1', 'posted_day_ago', 'hiring_person_link', 'location'], inplace=True)

# %%
df_clean.rename(columns= {'job_ID':'Job_ID', 'job':'Job', 'company_id':'Company_ID', 'company_name':'Company_Name', 'work_type':'Work_Location', 'full_time_remote':'Work_Type', 'no_of_employ':'No_of_Employees', 'no_of_application':'No_of_Applications', 'alumni':'No_of_Alumni', 'Hiring_person':'Hiring_Person', 'linkedin_followers':'Linkedin_Followers', 'job_details':'Job_Details', 'job_level':'Job_Level', 'industry':'Industry'}, inplace=True)

# %%
df_clean
# Out:
#           Job_ID                             Job  Company_ID  \
# 0     3471657636                    Data Analyst         523
# 1     3471669068                    Data Analyst         523
# 2     3474349934                    Data Analyst        2241
# 3     3472816027                    Data Analyst        1552
# 4     3473311511                    Data Analyst        2146
# ...          ...                             ...         ...
# 5838  3472039871              Back End Developer        1526
# 5839  3473194471               Software Engineer        2241
# 5840  3461005032                          Vue JS        2049
# 5841  3474305684                   iOS Developer        2241
# 5842  3459352801  Power train function developer         105
#
#                    Company_Name Work_Location   Work_Type No_of_Employees  \
# 0                     Crossover        Remote  Full-time      1001-5000
# 1                     Crossover        Remote  Full-time      1001-5000
# 2                        Uplers        Remote  Full-time      1001-5000
# 3                 PVAR SERVICES       On-site   Full-time           1-10
# 4      Timeline Freight Brokers       On-site   Full-time           1-10
# ...                         ...           ...         ...             ...
# 5838           Orion Innovation        Hybrid  Full-time     5001-10000
# 5839                     Uplers       On-site  Full-time      1001-5000
# 5840  Tata Consultancy Services       On-site  Full-time         10001+
# 5841                     Uplers        Remote  Full-time      1001-5000
# 5842                    Akkodis        Hybrid  Full-time         10001+
#
#       No_of_Applications  No_of_Alumni         Hiring_Person  \
# 0                  200.0          12.0         Not Available
# 1                  184.0          12.0         Not Available
# 2                  200.0           3.0          Shahid Ahmad
# 3                  200.0           NaN         Vartika Singh
# 4                    8.0           1.0               Manisha
# ...                  ...           ...                   ...
# 5838                25.0          24.0  Poornima Viswanathan
# 5839                18.0           3.0         Tejveer Singh
# 5840                15.0       10080.0          ANNIE ANTONY
# 5841                17.0           3.0           Arjun Jaggi
# 5842                43.0          27.0         Not Available
#
#       Linkedin_Followers                                        Job_Details  \
# 0              5395547.0  About the job Crossover is the world's #1 sour...
# 1              5395547.0  About the job Crossover is the world's #1 sour...
# 2                    NaN  About the job Profile: ML EngineersExperience:...
# 3                 2094.0  About the job Designation: Data AnalystLocatio...
# 4                    NaN  About the job The ideal candidate will use the...
# ...                  ...                                                ...
# 5838                 NaN  About the job The ideal candidate will show in...
# 5839                 NaN  About the job Experience: 4 - 8 yearsProfile: ...
# 5840          11923634.0  About the job Role- Vue js DeveloperExperience...
# 5841                 NaN  About the job Profile: iOS DeveloperExperience...
# 5842           1421090.0  About the job JD Powertrain Function Developer...
#
#               Job_Level                        Industry  \
# 0             Associate   IT Services and IT Consulting
# 1             Associate   IT Services and IT Consulting
# 2      Mid-Senior level   IT Services and IT Consulting
# 3                  None                            None
# 4                  None                            None
# ...                 ...                             ...
# 5838          Associate   IT Services and IT Consulting
# 5839   Mid-Senior level   IT Services and IT Consulting
# 5840   Mid-Senior level   IT Services and IT Consulting
# 5841   Mid-Senior level   IT Services and IT Consulting
# 5842   Mid-Senior level   IT Services and IT Consulting
#
#                      Country       State             City
# 0                      India       Delhi            Delhi
# 1                      India       Delhi        New Delhi
# 2     Greater Bengaluru Area        None             None
# 3                      India     Haryana         Gurugram
# 4                      India      Punjab  Mohali district
# ...                      ...         ...              ...
# 5838                   India      Kerala            Kochi
# 5839                   India     Haryana         Gurugram
# 5840                   India   Telangana        Hyderabad
# 5841                   India   Karnataka        Bengaluru
# 5842                   India   Karnataka        Bengaluru
#
# [5843 rows x 17 columns]

# %% [markdown]
# ## References
#
# Dataset: https://www.kaggle.com/datasets/shashankshukla123123/linkedin-job-data

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6f729d54-f55f-4523-b7b0-fcda4f0ebbf2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
